# %% [markdown]
# ### NOTEBOOK HIJO
# Este noteboock sera llamado y ejecutado por el principal noteboock que es Session01

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("v_msg","","Parametro entrada")

# %%
v_nombre=dbutils.widgets.get("v_msg")

print(f"El valor es: {v_nombre}")

# %%
print("Soy el notebook hijo del noteboook Session01")

# %%
dbutils.notebook.exit("Ejecucion con exito") 
 #este mensaje nos permite ver en el principal o padre(Session01)
